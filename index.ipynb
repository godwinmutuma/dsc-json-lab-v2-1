# %% [markdown]
# # JSON - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, you'll practice navigating JSON data structures.

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# * Practice using Python to load and parse JSON documents

# %% [markdown]
# ## Your Task: Find the Total Payments for Each Candidate
#
# We will be using the same dataset, `nyc_2001_campaign_finance.json`. The description of this file is:
#
# > A listing of public funds payments for candidates for City office during the 2001 election cycle
#
# For added context, the Ciy of New York provides matching funds for eligible contributions made to candidates, using various ratios depending on the contribution amount ([more details here](https://en.wikipedia.org/wiki/New_York_City_Campaign_Finance_Board#The_Campaign_Finance_Program)). So these are not the complete values of all funds raised by these candidates, they are the amounts matched by the city. For that reason we expect that some of the values will be identical for different candidates.
#
# The dataset is separated into `meta`, which contains metadata, and `data`, which contains the actual campaign finance records. You will need to use the information in `meta` to understand how to interpret the information in `data`.
#
# Your goal is to create a list of tuples, where the first value in each tuple is the name of a candidate in the 2001 election, and the second value is the total payments they received. The structure should look like this:
#
# ```python
# [
#     ("John Smith", 62184.00),
#     ("Jane Doe", 133146.00),
#     ...
# ]
# ```
#
# The list should contain 284 tuples, since there were 284 candidates.

# %% [markdown]
# ## Open the Dataset
#
# Import the `json` module, open the `nyc_2001_campaign_finance.json` file using the built-in Python `open` function, and load all of the data from the file into a Python object using `json.load`.
#
# Assign the result of `json.load` to the variable name `data`.

# %%
# Your code here
import json
with open('nyc_2001_campaign_finance.json') as f:
    data = json.load(f)

# %% [markdown]
# Recall the overall structure of this dataset:

# %%
# Run this cell without changes

print(f"The overall data type is {type(data)}")
print(f"The keys are {list(data.keys())}")
print()
print("The value associated with the 'meta' key has metadata, including all of these attributes:")
print(list(data['meta']['view'].keys()))
print()
print(f"The value associated with the 'data' key is a list of {len(data['data'])} records")
# Out:
# The overall data type is <class 'dict'>
# The keys are ['meta', 'data']
#
# The value associated with the 'meta' key has metadata, including all of these attributes:
# ['id', 'name', 'attribution', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags']
#
# The value associated with the 'data' key is a list of 285 records

# %% [markdown]
# ## Find the Column Names
#
# We know that each record in the data list looks something like this:

# %%
# Run this cell without changes
data['data'][1]
# Out:
# [2,
#  '9D257416-581A-4C42-85CC-B6EAD9DED97F',
#  2,
#  1315925633,
#  '392904',
#  1315925633,
#  '392904',
#  '{\n}',
#  '2001',
#  'B4',
#  'Aboulafia, Sandy',
#  '5',
#  None,
#  '44',
#  'P',
#  '45410.00',
#  '0',
#  '0',
#  '45410.00']

# %% [markdown]
# We could probably guess which of those values is the candidate name, but it's unclear which value is the total payments received. To get that information, we need to look at the metadata.
#
# Investigate the value of `data['meta']['view']['columns']`.
#
# Let `data['meta']['view']['columns']` be called `column_data`. Verify that `column_data` results in a list.

# %%
# Your code here (create more cells as needed)
column_data = data['meta']['view']['columns']
column_data
# Out:
# [{'id': -1,
#   'name': 'sid',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':sid',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'id',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':id',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'position',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':position',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'created_at',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':created_at',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'created_meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':created_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'updated_at',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':updated_at',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'updated_meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':updated_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': 75768833,
#   'name': 'ELECTION',
#   'dataTypeName': 'number',
#   'fieldName': 'election',
#   'position': 2,
#   'renderTypeName': 'number',
#   'tableColumnId': 1518991,
#   'width': 196,
#   'cachedContents': {'non_null': 284,
#    'average': '2001',
#    'largest': '2001',
#    'null': 1,
#    'top': [{'item': '2001', 'count': 20}],
#    'smallest': '2001',
#    'sum': '568284'},
#   'format': {'precisionStyle': 'standard',
#    'noCommas': 'true',
#    'align': 'right'}},
#  {'id': 75768834,
#   'name': 'CANDID',
#   'dataTypeName': 'text',
#   'fieldName': 'candid',
#   'position': 3,
#   'renderTypeName': 'text',
#   'tableColumnId': 1518992,
#   'width': 172,
#   'cachedContents': {'non_null': 285,
#    'largest': 'YA',
#    'null': 0,
#    'top': [{'item': '490', 'count': 20},
#     {'item': '577', 'count': 19},
#     {'item': 'GF', 'count': 18},
#     {'item': '265', 'count': 17},
#     {'item': '549', 'count': 16},
#     {'item': '260', 'count': 15},
#     {'item': 'DH', 'count': 14},
#     {'item': '168', 'count': 13},
#     {'item': '561', 'count': 12},
#     {'item': '317', 'count': 11},
#     {'item': '240', 'count': 10},
#     {'item': 'B1', 'count': 9},
#     {'item': '337', 'count': 8},
#     {'item': '202', 'count': 7},
#     {'item': 'DP', 'count': 6},
#     {'item': '554', 'count': 5},
#     {'item': '529', 'count': 4},
#     {'item': '521', 'count': 3},
#     {'item': 'CY', 'count': 2},
#     {'item': '327', 'count': 1}],
#    'smallest': '148'},
#   'format': {}},
#  {'id': 75768835,
#   'name': 'CANDNAME',
#   'dataTypeName': 'text',
#   'fieldName': 'candname',
#   'position': 4,
#   'renderTypeName': 'text',
#   'tableColumnId': 1518993,
#   'width': 196,
#   'cachedContents': {'non_null': 285,
#    'largest': 'Zett, Lori M',
#    'null': 0,
#    'top': [{'item': 'Taitt, Samuel A', 'count': 20},
#     {'item': 'Taliaferro, Phyllis', 'count': 19},
#     {'item': 'Taveras, Germania', 'count': 18},
#     {'item': 'Thakral, Jairam D', 'count': 17},
#     {'item': 'Thomas, Carl W', 'count': 16},
#     {'item': 'Thompson, Jr., William C', 'count': 15},
#     {'item': 'Tiraco, Joseph E', 'count': 14},
#     {'item': 'Toney, Vaughan', 'count': 13},
#     {'item': 'Toppin, Roger N', 'count': 12},
#     {'item': 'Torres, Mario A', 'count': 11},
#     {'item': 'Vallone, Jr., Peter F', 'count': 10},
#     {'item': 'Vallone, Peter F', 'count': 9},
#     {'item': 'Van Bramer, James G', 'count': 8},
#     {'item': 'Vann, Albert', 'count': 7},
#     {'item': 'Vargas, Ruben Dario', 'count': 6},
#     {'item': 'Vassos, Sandra', 'count': 5},
#     {'item': 'Vernet, Jean D', 'count': 4},
#     {'item': 'Viest, Nicholas D', 'count': 3},
#     {'item': 'Villaverde, Sergio', 'count': 2},
#     {'item': 'Vogel, Mark H', 'count': 1}],
#    'smallest': 'Aboulafia, Sandy'},
#   'format': {}},
#  {'id': 75768836,
#   'name': 'OFFICECD',
#   'dataTypeName': 'number',
#   'fieldName': 'officecd',
#   'position': 5,
#   'renderTypeName': 'number',
#   'tableColumnId': 1518994,
#   'width': 196,
#   'cachedContents': {'non_null': 284,
#    'average': '4.700704225352113',
#    'largest': '5',
#    'null': 1,
#    'top': [{'item': '5', 'count': 20},
#     {'item': '1', 'count': 19},
#     {'item': '3', 'count': 18},
#     {'item': '4', 'count': 17},
#     {'item': '2', 'count': 16}],
#    'smallest': '1',
#    'sum': '1335'},
#   'format': {}},
#  {'id': 75768837,
#   'name': 'OFFICEBORO',
#   'dataTypeName': 'text',
#   'fieldName': 'officeboro',
#   'position': 6,
#   'renderTypeName': 'text',
#   'tableColumnId': 1518995,
#   'width': 220,
#   'cachedContents': {'non_null': 21,
#    'largest': 'X',
#    'null': 264,
#    'top': [{'item': 'OFFICEBORO', 'count': 20},
#     {'item': 'X', 'count': 19},
#     {'item': 'M', 'count': 18},
#     {'item': 'K', 'count': 17},
#     {'item': 'Q', 'count': 16},
#     {'item': 'S', 'count': 15}],
#    'smallest': 'K'},
#   'format': {}},
#  {'id': 75768838,
#   'name': 'OFFICEDIST',
#   'dataTypeName': 'number',
#   'fieldName': 'officedist',
#   'position': 7,
#   'renderTypeName': 'number',
#   'tableColumnId': 1518996,
#   'width': 220,
#   'cachedContents': {'non_null': 245,
#    'average': '26.33061224489796',
#    'largest': '51',
#    'null': 40,
#    'top': [{'item': '7', 'count': 20},
#     {'item': '32', 'count': 19},
#     {'item': '37', 'count': 18},
#     {'item': '28', 'count': 17},
#     {'item': '19', 'count': 16},
#     {'item': '39', 'count': 15},
#     {'item': '35', 'count': 14},
#     {'item': '42', 'count': 13},
#     {'item': '31', 'count': 12},
#     {'item': '6', 'count': 11},
#     {'item': '47', 'count': 10},
#     {'item': '20', 'count': 9},
#     {'item': '1', 'count': 8},
#     {'item': '27', 'count': 7},
#     {'item': '26', 'count': 6},
#     {'item': '10', 'count': 5},
#     {'item': '34', 'count': 4},
#     {'item': '45', 'count': 3},
#     {'item': '40', 'count': 2},
#     {'item': '12', 'count': 1}],
#    'smallest': '1',
#    'sum': '6451'},
#   'format': {}},
#  {'id': 75768839,
#   'name': 'CANCLASS',
#   'dataTypeName': 'text',
#   'fieldName': 'canclass',
#   'position': 8,
#   'renderTypeName': 'text',
#   'tableColumnId': 1518997,
#   'width': 196,
#   'cachedContents': {'non_null': 285,
#    'largest': 'P',
#    'null': 0,
#    'top': [{'item': 'CANCLASS', 'count': 20}, {'item': 'P', 'count': 19}],
#    'smallest': 'CANCLASS'},
#   'format': {}},
#  {'id': 75768840,
#   'name': 'PRIMARYPAY',
#   'dataTypeName': 'number',
#   'fieldName': 'primarypay',
#   'position': 9,
#   'renderTypeName': 'number',
#   'tableColumnId': 1518998,
#   'width': 220,
#   'cachedContents': {'non_null': 284,
#    'average': '112243.9612676056',
#    'largest': '2846148.00',
#    'null': 1,
#    'top': [{'item': '75350.00', 'count': 20},
#     {'item': '0', 'count': 19},
#     {'item': '91333.00', 'count': 18},
#     {'item': '69780.00', 'count': 17},
#     {'item': '22172.00', 'count': 16},
#     {'item': '65356.00', 'count': 15},
#     {'item': '11423.00', 'count': 14},
#     {'item': '60152.00', 'count': 13},
#     {'item': '75040.00', 'count': 12},
#     {'item': '62436.00', 'count': 11},
#     {'item': '42075.00', 'count': 10},
#     {'item': '74920.00', 'count': 9},
#     {'item': '38088.00', 'count': 8},
#     {'item': '74850.00', 'count': 7},
#     {'item': '89502.00', 'count': 6},
#     {'item': '74350.00', 'count': 5},
#     {'item': '58348.00', 'count': 4},
#     {'item': '55100.00', 'count': 3},
#     {'item': '508893.00', 'count': 2},
#     {'item': '74750.00', 'count': 1}],
#    'smallest': '0',
#    'sum': '31877285.00'},
#   'format': {}},
#  {'id': 75768841,
#   'name': 'GENERALPAY',
#   'dataTypeName': 'number',
#   'fieldName': 'generalpay',
#   'position': 10,
#   'renderTypeName': 'number',
#   'tableColumnId': 1518999,
#   'width': 220,
#   'cachedContents': {'non_null': 284,
#    'average': '28753.57394366197',
#    'largest': '976545.00',
#    'null': 1,
#    'top': [{'item': '0', 'count': 20},
#     {'item': '75350.00', 'count': 19},
#     {'item': '201131.00', 'count': 18},
#     {'item': '39760.00', 'count': 17},
#     {'item': '57796.00', 'count': 16},
#     {'item': '75200.00', 'count': 15},
#     {'item': '68234.00', 'count': 14},
#     {'item': '5732.00', 'count': 13},
#     {'item': '58488.00', 'count': 12},
#     {'item': '62184.00', 'count': 11},
#     {'item': '44748.00', 'count': 10},
#     {'item': '21946.00', 'count': 9},
#     {'item': '70500.00', 'count': 8}],
#    'smallest': '0',
#    'sum': '8166015.00'},
#   'format': {}},
#  {'id': 75768842,
#   'name': 'RUNOFFPAY',
#   'dataTypeName': 'number',
#   'fieldName': 'runoffpay',
#   'position': 11,
#   'renderTypeName': 'number',
#   'tableColumnId': 1519000,
#   'width': 208,
#   'cachedContents': {'non_null': 284,
#    'average': '7776.778169014085',
#    'largest': '711537.00',
#    'null': 1,
#    'top': [{'item': '0', 'count': 20},
#     {'item': '267331.00', 'count': 19},
#     {'item': '574387.00', 'count': 18},
#     {'item': '303270.00', 'count': 17},
#     {'item': '711537.00', 'count': 16},
#     {'item': '114407.00', 'count': 15},
#     {'item': '237673.00', 'count': 14}],
#    'smallest': '0',
#    'sum': '2208605.00'},
#   'format': {}},
#  {'id': 75768843,
#   'name': 'TOTALPAY',
#   'dataTypeName': 'number',
#   'fieldName': 'totalpay',
#   'position': 12,
#   'renderTypeName': 'number',
#   'tableColumnId': 1519001,
#   'width': 196,
#   'cachedContents': {'non_null': 284,
#    'average': '148774.3133802817',
#    'largest': '4534230.00',
#    'null': 1,
#    'top': [{'item': '0', 'count': 20},
#     {'item': '75350.00', 'count': 19},
#     {'item': '150700.00', 'count': 18},
#     {'item': '2458534.00', 'count': 17},
#     {'item': '133146.00', 'count': 16},
#     {'item': '75200.00', 'count': 15},
#     {'item': '68234.00', 'count': 14},
#     {'item': '70664.00', 'count': 13},
#     {'item': '58488.00', 'count': 12},
#     {'item': '50112.00', 'count': 11},
#     {'item': '62184.00', 'count': 10},
#     {'item': '44748.00', 'count': 9},
#     {'item': '21946.00', 'count': 8},
#     {'item': '41656.00', 'count': 7},
#     {'item': '61260.00', 'count': 6},
#     {'item': '145850.00', 'count': 5},
#     {'item': '35808.00', 'count': 4},
#     {'item': '12172.00', 'count': 3}],
#    'smallest': '0',
#    'sum': '42251905.00'},
#   'format': {}}]

# %% [markdown]
# Now look at the first few entries of `column_data`.
#
# The result should look something like this:
#
# ```python
# [
#     "sid",
#     "id",
#     "position",
#     ...
# ]
# ```

# %%
# Your code here (create more cells as needed)
column_data[9]["name"]
# With a list, it's often useful to look at the
# first entry, or first few entries
# Out:
# 'CANDID'

# %% [markdown]
# `column_data` currently contains significantly more information than we need. Extract just the values associated with the `name` keys using list comprehension, so we have a list of the column names.
#
# Now name this variable `column_names`.

# %%
# Your code here (create more cells as needed)

# Assuming column_data is already defined
column_names = [entry["name"] for entry in column_data]

# Display the list of column names
print(column_names)
# Out:
# ['sid', 'id', 'position', 'created_at', 'created_meta', 'updated_at', 'updated_meta', 'meta', 'ELECTION', 'CANDID', 'CANDNAME', 'OFFICECD', 'OFFICEBORO', 'OFFICEDIST', 'CANCLASS', 'PRIMARYPAY', 'GENERALPAY', 'RUNOFFPAY', 'TOTALPAY']

# %%
# Run this cell without changes

# There should be 19 names
assert len(column_names) == 19
# CANDNAME and TOTALPAY should be in there
assert "CANDNAME" in column_names and "TOTALPAY" in column_names

# %% [markdown]
# Now we know what each of the columns represents.
#
# The columns we are looking for are called `CANDNAME` and `TOTALPAY`. Now that we have this list, we should be able to figure out which of the values in each record lines up with those column names.

# %% [markdown]
# ## Loop Over the Records to Find the Names and Payments
#
# The data records are contained in `data['data']`.
#
# To loop over the records to find the names and payments, first we need to determine the indices of the candidate names and the total payments.
#
# Let `name_index` be the column names of `CANDNAME` and `total_payments_index` be the column names of `TOTALPAY`. After correctly defining `name_index` and `total_payments_index`, print their respective indices.

# %%
# Your code here (create more cells as needed)

# In theory we could just look at the list and
# count by hand to figure out the index of these
# strings, but Python can do it for us

name_index = column_names.index('CANDNAME')
total_payments_index = column_names.index('TOTALPAY')

for record in data['data']:
    candidate_name = record[name_index]
    total_payment = record[total_payments_index]
    print(f"Candidate: {candidate_name}, Total Payment: {total_payment}")
# Out:
# Candidate: CANDNAME, Total Payment: None
# Candidate: Aboulafia, Sandy, Total Payment: 45410.00
# Candidate: Adams, Jackie R, Total Payment: 11073.00
# Candidate: Addabbo, Joseph P, Total Payment: 149320.00
# Candidate: Alamo-Estrada, Agustin, Total Payment: 27400.00
# Candidate: Allen, William A, Total Payment: 62990.00
# Candidate: Alleyne, Alithia, Total Payment: 0
# Candidate: Alonso, Miguel, Total Payment: 36801.00
# Candidate: Andrews, Jr., Anthony D, Total Payment: 88736.00
# Candidate: Ariola, JoAnn, Total Payment: 69816.00
# Candidate: Avella, Tony, Total Payment: 150520.00
# Candidate: Bader, Paul, Total Payment: 75350.00
# Candidate: Badillo, Herman, Total Payment: 356723.00
# Candidate: Baez, Maria, Total Payment: 90262.00
# Candidate: Baldwin-Ferguson, Imogene, Total Payment: 0
# Candidate: Banks, Steven R, Total Payment: 75350.00
# Candidate: Barron, Charles, Total Payment: 92498.00
# Candidate: Bastone, Terry A, Total Payment: 47820.00
# Candidate: Benjamin, Michael A, Total Payment: 108226.00
# Candidate: Berman, Herbert E, Total Payment: 1576860.00
# Candidate: Bernace, Victor A, Total Payment: 19520.00
# Candidate: Bilal, Charles A, Total Payment: 0
# Candidate: Blake, James, Total Payment: 51676.00
# Candidate: Bloodsaw, Daryl G, Total Payment: 37312.00
# Candidate: Bouchard, Michelle, Total Payment: 65704.00
# Candidate: Brewer, Gale A, Total Payment: 150700.00
# Candidate: Brook Krasny, Alec, Total Payment: 66304.00
# Candidate: Brooks, Curtis, Total Payment: 0
# Candidate: Brown, Everly D, Total Payment: 0
# Candidate: Brown, Michael E, Total Payment: 0
# Candidate: Cammarata, Joseph F, Total Payment: 73868.00
# Candidate: Carrion, Jr., Adolfo, Total Payment: 431802.00
# Candidate: Carroll, John W, Total Payment: 75350.00
# Candidate: Castellanos, Francesca M, Total Payment: 21292.00
# Candidate: Cermeli, Robert, Total Payment: 49572.00
# Candidate: Chan, Louisa M, Total Payment: 29444.00
# Candidate: Cheliotes, Arthur, Total Payment: 75350.00
# Candidate: Chen, Ethel T, Total Payment: 75350.00
# Candidate: Chin, Margaret S, Total Payment: 164123.00
# Candidate: Chin, Rockwell J, Total Payment: 166683.00
# Candidate: Chou, Evergreen C, Total Payment: 0
# Candidate: Ciafone, John J, Total Payment: 0
# Candidate: Clarke, Amanda L, Total Payment: 0
# Candidate: Clarke, Yvette D, Total Payment: 77922.00
# Candidate: Cohn, Steven D, Total Payment: 147160.00
# Candidate: Colon, Willie, Total Payment: 0
# Candidate: Comrie, Leroy G, Total Payment: 71388.00
# Candidate: Conley, Joseph T, Total Payment: 75350.00
# Candidate: Cooper-Gregory, Helen A, Total Payment: 75350.00
# Candidate: Crowley, Elizabeth S, Total Payment: 145096.00
# Candidate: Curran, Robert E, Total Payment: 0
# Candidate: Curry, Anthony, Total Payment: 0
# Candidate: Davis, James E, Total Payment: 122382.00
# Candidate: de Blasio, Bill, Total Payment: 142885.00
# Candidate: Del Giorno, Jon R, Total Payment: 75350.00
# Candidate: Del Villar, Angel, Total Payment: 0
# Candidate: DeMarco Jr., Alexander A, Total Payment: 0
# Candidate: Detiege-Cormier, Roy-Pierre, Total Payment: 0
# Candidate: Diamondstone, Kenneth A, Total Payment: 94946.00
# Candidate: DiBrienza, Stephen, Total Payment: 1336655.00
# Candidate: Dilan, Erik M, Total Payment: 80904.00
# Candidate: Dotson, Heyward H, Total Payment: 0
# Candidate: Doukas, Peter G, Total Payment: 65048.00
# Candidate: Eagan, Ann, Total Payment: 0
# Candidate: Eisland, June M, Total Payment: 316548.00
# Candidate: Espada, Jr., Pedro, Total Payment: 0
# Candidate: Espada, Pedro G, Total Payment: 55900.00
# Candidate: Evans, Jeanette, Total Payment: 0
# Candidate: Faison, Barbara, Total Payment: 0
# Candidate: Falcon-Lopez, Miriam T, Total Payment: 0
# Candidate: Farrakhan, Abdur Rahman, Total Payment: 0
# Candidate: Farrell, Matthew J, Total Payment: 75350.00
# Candidate: Felder, Simcha, Total Payment: 150700.00
# Candidate: Ferrer, Fernando, Total Payment: 2871933.00
# Candidate: Fidler, Lewis A, Total Payment: 142141.00
# Candidate: Fields, C. Virginia, Total Payment: 444452.00
# Candidate: Fields, Jessie, Total Payment: 135904.00
# Candidate: Fisher, Kenneth K, Total Payment: 647350.00
# Candidate: Flaxman, Sheila S, Total Payment: 0
# Candidate: Flores-Vazquez, Martha, Total Payment: 39476.00
# Candidate: Foley, Ronald G, Total Payment: 0
# Candidate: Foster, Helen Diane, Total Payment: 131798.00
# Candidate: Frank, John D, Total Payment: 52968.00
# Candidate: Fratta, John A, Total Payment: 91333.00
# Candidate: Freed, Kathryn E, Total Payment: 626484.00
# Candidate: Fullard, Henrietta, Total Payment: 0
# Candidate: Gadson, Jeanette, Total Payment: 521969.00
# Candidate: Gallagher, Dennis P, Total Payment: 75350.00
# Candidate: Gangemi, Ursula A, Total Payment: 48480.00
# Candidate: Gennaro, James F, Total Payment: 146314.00
# Candidate: Gerson, Alan J, Total Payment: 165783.00
# Candidate: Gioia, Eric, Total Payment: 148266.00
# Candidate: Golden, Martin J, Total Payment: 75350.00
# Candidate: Golding, Kenneth B, Total Payment: 0
# Candidate: Golub, Jay, Total Payment: 19900.00
# Candidate: Gonzalez-Jarrin, Aida A, Total Payment: 71940.00
# Candidate: Gotbaum, Betsy F, Total Payment: 1625090.00
# Candidate: Graziano, Paul D, Total Payment: 27320.00
# Candidate: Greco, Jr., Rudolph E, Total Payment: 75350.00
# Candidate: Green, Mark, Total Payment: 4534230.00
# Candidate: Greenwood, Doreen A, Total Payment: 78932.00
# Candidate: Gresser, Carol A, Total Payment: 596045.00
# Candidate: Grodenchik, Barry, Total Payment: 147626.00
# Candidate: Gutnik, Oleg, Total Payment: 90908.00
# Candidate: Haber, Jason S, Total Payment: 0
# Candidate: Hammerman, Craig R, Total Payment: 75350.00
# Candidate: Hernandez, Louis R, Total Payment: 10976.00
# Candidate: Herz, David R, Total Payment: 0
# Candidate: Hevesi, Alan G, Total Payment: 2641247.00
# Candidate: Hikind, Libby N, Total Payment: 124753.00
# Candidate: Hochhauser, Joseph K, Total Payment: 25020.00
# Candidate: Howell, Carol B, Total Payment: 0
# Candidate: Hoylman, Brad M, Total Payment: 91333.00
# Candidate: Hughes, Michael B, Total Payment: 0
# Candidate: Hui, Kwong T, Total Payment: 142973.00
# Candidate: Hunter, Robert A, Total Payment: 0
# Candidate: Hylton, Christian B, Total Payment: 51732.00
# Candidate: Iannece, Jerry M, Total Payment: 104602.00
# Candidate: Imprescia, Richard V, Total Payment: 0
# Candidate: Jackson, Gregory, Total Payment: 0
# Candidate: Jackson, Robert, Total Payment: 107262.00
# Candidate: James, Letitia, Total Payment: 147994.00
# Candidate: Jannaccio, Richard, Total Payment: 28736.00
# Candidate: Jefferson, Charlotte R, Total Payment: 53273.00
# Candidate: Jeffries-El, Joseph, Total Payment: 0
# Candidate: Jenkins, Cynthia, Total Payment: 0
# Candidate: Jenkins, Patrick B, Total Payment: 0
# Candidate: Jennings, Allan W, Total Payment: 41344.00
# Candidate: Jodha, Rameshwar, Total Payment: 0
# Candidate: Jorge, Chris, Total Payment: 45580.00
# Candidate: Kann, Jerry, Total Payment: 0
# Candidate: Katz, Melinda R, Total Payment: 150700.00
# Candidate: Kaufman, Jordan, Total Payment: 0
# Candidate: Kearney, Michael G, Total Payment: 75350.00
# Candidate: Kinard, Stanley, Total Payment: 0
# Candidate: Koppell, G. Oliver, Total Payment: 148090.00
# Candidate: Kramer, Kenny, Total Payment: 0
# Candidate: Lanza, Andrew J, Total Payment: 110891.00
# Candidate: Lasher, Susan, Total Payment: 53976.00
# Candidate: Law, Ronald, Total Payment: 0
# Candidate: Leffler, Sheldon S, Total Payment: 296084.00
# Candidate: Leighton, Thomas K, Total Payment: 0
# Candidate: Lesczynski, James L, Total Payment: 0
# Candidate: Levine, Mark D, Total Payment: 73320.00
# Candidate: Levy, Abraham, Total Payment: 55412.00
# Candidate: Lewis, Anna R, Total Payment: 77112.00
# Candidate: Lewis, Edward J, Total Payment: 30720.00
# Candidate: Lewis, Prince D, Total Payment: 0
# Candidate: Liu, John C, Total Payment: 150520.00
# Candidate: Lizardo, Roberto E, Total Payment: 75350.00
# Candidate: Lobo, Renee, Total Payment: 52672.00
# Candidate: Lopez, Margarita, Total Payment: 143682.00
# Candidate: Luciano, Felipe, Total Payment: 47720.00
# Candidate: Maio, Danniel S, Total Payment: 0
# Candidate: Mandell, Linda, Total Payment: 0
# Candidate: Marchant, Garth I, Total Payment: 110086.00
# Candidate: Markowitz, Marty, Total Payment: 1166294.00
# Candidate: Marshall, Helen M, Total Payment: 647173.00
# Candidate: Martin, Yolanda J, Total Payment: 0
# Candidate: Martinez, George, Total Payment: 0
# Candidate: Martinez, Juan D, Total Payment: 75350.00
# Candidate: Martinez, Miguel, Total Payment: 128786.00
# Candidate: Mascitti, Michael A, Total Payment: 0
# Candidate: Mateo, Heriberto, Total Payment: 68040.00
# Candidate: Mattera, Gloria, Total Payment: 31704.00
# Candidate: McCleary, Michelle L, Total Payment: 0
# Candidate: McMahon, Michael E, Total Payment: 150700.00
# Candidate: Miller, Robert J, Total Payment: 135118.00
# Candidate: Miranda, Anthony, Total Payment: 0
# Candidate: Molinaro, James P, Total Payment: 879456.00
# Candidate: Monserrate, Hiram, Total Payment: 74430.00
# Candidate: Montano, Armando, Total Payment: 90883.00
# Candidate: Moran, Janey, Total Payment: 56284.00
# Candidate: Morgan, Ishmael J, Total Payment: 21800.00
# Candidate: Morillo, Pedro, Total Payment: 0
# Candidate: Morisete-Romero, Victor, Total Payment: 75350.00
# Candidate: Moskowitz, Eva S, Total Payment: 150500.00
# Candidate: Nelson, Michael C, Total Payment: 63168.00
# Candidate: Norman, Edward J, Total Payment: 65496.00
# Candidate: Nunes-Ueno, Paulo, Total Payment: 0
# Candidate: O'Donovan, Jerome X, Total Payment: 647350.00
# Candidate: O'Malley, Patrick, Total Payment: 68724.00
# Candidate: Oddo, James S, Total Payment: 75350.00
# Candidate: Ortiz, Jr., Edwin O, Total Payment: 46752.00
# Candidate: Palmer, Samuel E, Total Payment: 75350.00
# Candidate: Park, Terence Y, Total Payment: 67286.00
# Candidate: Parker, Kevin, Total Payment: 75350.00
# Candidate: Perez, Richard, Total Payment: 63756.00
# Candidate: Perkins, Bill, Total Payment: 121650.00
# Candidate: Pina, Tirso S, Total Payment: 0
# Candidate: Poisson, Lola, Total Payment: 0
# Candidate: Puello, Giovanni, Total Payment: 50852.00
# Candidate: Pugliese, Anthony J, Total Payment: 75350.00
# Candidate: Purcell, Frances G, Total Payment: 67932.00
# Candidate: Quinn, Christine C, Total Payment: 0
# Candidate: Recchia, Domenic, Total Payment: 136327.00
# Candidate: Reed, Philip, Total Payment: 150700.00
# Candidate: Reich, David, Total Payment: 75350.00
# Candidate: Reiss, David J, Total Payment: 46048.00
# Candidate: Reyna, Diana, Total Payment: 150302.00
# Candidate: Rivera, Joel, Total Payment: 70444.00
# Candidate: Roberts, Edward A, Total Payment: 37780.00
# Candidate: Rodriguez, Angel, Total Payment: 75350.00
# Candidate: Rodriguez, Elizabeth, Total Payment: 31685.00
# Candidate: Rodriguez, Ydanis A, Total Payment: 116586.00
# Candidate: Romero, Michelle, Total Payment: 22172.00
# Candidate: Rose, Deborah, Total Payment: 132466.00
# Candidate: Rosero, Luis, Total Payment: 65356.00
# Candidate: Ruiz, Jr., Israel, Total Payment: 11423.00
# Candidate: Rupnarain, Trevor K, Total Payment: 75350.00
# Candidate: Saffran, Dennis J, Total Payment: 75350.00
# Candidate: Sanchez, Cynthia M, Total Payment: 0
# Candidate: Sanders, Jr., James J, Total Payment: 60152.00
# Candidate: Sansivieri, Linda, Total Payment: 75040.00
# Candidate: Sauer, Larry M, Total Payment: 62436.00
# Candidate: Saunders, Shirley J, Total Payment: 75350.00
# Candidate: Saunders, William J, Total Payment: 42075.00
# Candidate: Schulman, Lynn C, Total Payment: 74920.00
# Candidate: Schultheis, Magdalena U, Total Payment: 38088.00
# Candidate: Scissura, Carlo A, Total Payment: 75350.00
# Candidate: Seabrook, Larry B, Total Payment: 102426.00
# Candidate: Sears, Helen, Total Payment: 117915.00
# Candidate: Seeman, Craig A, Total Payment: 31632.00
# Candidate: Sementilli, Egidio J, Total Payment: 89502.00
# Candidate: Seminara, Joanne, Total Payment: 150700.00
# Candidate: Seminerio, John, Total Payment: 74350.00
# Candidate: Serrano, Jose M, Total Payment: 75160.00
# Candidate: Sharpe, Wellington, Total Payment: 0
# Candidate: Shepard, Joyce P, Total Payment: 55100.00
# Candidate: Sica, Philip T, Total Payment: 14632.00
# Candidate: Siegel, Norman H, Total Payment: 623300.00
# Candidate: Simon, Lew M, Total Payment: 74750.00
# Candidate: Simons, Earl G, Total Payment: 0
# Candidate: Singer, Pat, Total Payment: 61324.00
# Candidate: Singh, Inderjit, Total Payment: 0
# Candidate: Smith, Larry, Total Payment: 32189.00
# Candidate: Snyder, Gary D, Total Payment: 19124.00
# Candidate: Spalter, Laura, Total Payment: 75350.00
# Candidate: Spencer, Tony, Total Payment: 50782.00
# Candidate: Spirgel, Samuel C, Total Payment: 97454.00
# Candidate: Spitz, George N, Total Payment: 0
# Candidate: Stabile, Alfonso C, Total Payment: 0
# Candidate: Stavitsky, Inna, Total Payment: 53384.00
# Candidate: Stewart, Kendall B, Total Payment: 75350.00
# Candidate: Straniere, Robert A, Total Payment: 288388.00
# Candidate: Stringer, Scott M, Total Payment: 1223721.00
# Candidate: Taitt, Samuel A, Total Payment: 58530.00
# Candidate: Taliaferro, Phyllis, Total Payment: 0
# Candidate: Taveras, Germania, Total Payment: 0
# Candidate: Thakral, Jairam D, Total Payment: 75064.00
# Candidate: Thomas, Carl W, Total Payment: 0
# Candidate: Thompson, Jr., William C, Total Payment: 1096359.00
# Candidate: Tiraco, Joseph E, Total Payment: 0
# Candidate: Toney, Vaughan, Total Payment: 75350.00
# Candidate: Toppin, Roger N, Total Payment: 0
# Candidate: Torres, Mario A, Total Payment: 82082.00
# Candidate: Vallone, Jr., Peter F, Total Payment: 114910.00
# Candidate: Vallone, Peter F, Total Payment: 2458534.00
# Candidate: Van Bramer, James G, Total Payment: 133146.00
# Candidate: Vann, Albert, Total Payment: 75200.00
# Candidate: Vargas, Ruben Dario, Total Payment: 0
# Candidate: Vassos, Sandra, Total Payment: 68234.00
# Candidate: Vernet, Jean D, Total Payment: 70664.00
# Candidate: Viest, Nicholas D, Total Payment: 58488.00
# Candidate: Villaverde, Sergio, Total Payment: 0
# Candidate: Vogel, Mark H, Total Payment: 50112.00
# Candidate: Wai, Sidique A, Total Payment: 62184.00
# Candidate: Walker, John P, Total Payment: 44748.00
# Candidate: Walker, Willie, Total Payment: 0
# Candidate: Walsh, Ryan J, Total Payment: 21946.00
# Candidate: Wasserman, Abraham E, Total Payment: 41656.00
# Candidate: Wein, Joseph Funicell, Total Payment: 61260.00
# Candidate: Weir, Elias J, Total Payment: 0
# Candidate: Weprin, David I, Total Payment: 145850.00
# Candidate: Whitney, W Ruth, Total Payment: 0
# Candidate: Willebrand, Julia A, Total Payment: 0
# Candidate: Williams, Charles, Total Payment: 35808.00
# Candidate: Williams, Peter M, Total Payment: 75350.00
# Candidate: Williams-Pereira, Dorothy, Total Payment: 0
# Candidate: Wilson, Jay R, Total Payment: 0
# Candidate: Wilson, John H, Total Payment: 0
# Candidate: Wooten, Donald T, Total Payment: 0
# Candidate: Yassky, David, Total Payment: 150700.00
# Candidate: Zapiti, Mike, Total Payment: 12172.00
# Candidate: Zett, Lori M, Total Payment: 0

# %% [markdown]
# Now loop over the records in `data['data']` and extract the name from `name_index` and total payment from `total_payments_index`. Make sure you convert the total payment to a float, then make a tuple representing that candidate. Append the tuple to an overall list of results called `candidate_total_payments`.
#
# Recall that the first (`0`-th) one is more of a header and should be skipped over.
#
# To verify that your loop worked, print the first five and the last five records.

# %%
# Your code here (create more cells as needed)

# Initialize the list to store results
candidate_total_payments = []

# Loop over the records and extract names and payments
for record in data['data'][1:]:  # Skip the header (0-th) record
    name = record[name_index]
    total_payment = float(record[total_payments_index])
    candidate_total_payments.append((name, total_payment))

# Print the first five and last five records
print("First five records:")
print(candidate_total_payments[:5])

print("Last five records:")
print(candidate_total_payments[-5:])
# Out:
# First five records:
# [('Aboulafia, Sandy', 45410.0), ('Adams, Jackie R', 11073.0), ('Addabbo, Joseph P', 149320.0), ('Alamo-Estrada, Agustin', 27400.0), ('Allen, William A', 62990.0)]
# Last five records:
# [('Wilson, John H', 0.0), ('Wooten, Donald T', 0.0), ('Yassky, David', 150700.0), ('Zapiti, Mike', 12172.0), ('Zett, Lori M', 0.0)]

# %%
# Run this cell without changes

# There should be 284 records
assert len(candidate_total_payments) == 284

# Each record should contain a tuple
assert type(candidate_total_payments[0]) == tuple

# That tuple should contain a string and a number
assert len(candidate_total_payments[0]) == 2
assert type(candidate_total_payments[0][0]) == str
assert type(candidate_total_payments[0][1]) == float

# %% [markdown]
# Now that we have this result, we can answer questions like: *which candidates received the most total payments from the city*?

# %%
# Run this cell without changes

# Print the top 10 candidates by total payments
sorted(candidate_total_payments, key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('Green, Mark', 4534230.0),
#  ('Ferrer, Fernando', 2871933.0),
#  ('Hevesi, Alan G', 2641247.0),
#  ('Vallone, Peter F', 2458534.0),
#  ('Gotbaum, Betsy F', 1625090.0),
#  ('Berman, Herbert E', 1576860.0),
#  ('DiBrienza, Stephen', 1336655.0),
#  ('Stringer, Scott M', 1223721.0),
#  ('Markowitz, Marty', 1166294.0),
#  ('Thompson, Jr., William C', 1096359.0)]

# %% [markdown]
# Since you found all of the column names, it is also possible to display all of the data in a nice tabular format using pandas. That code would look like this:

# %%
# Run this cell without changes

import pandas as pd

pd.DataFrame(data=data['data'][1:], columns=column_names)
# Out:
#      sid                                    id  position  created_at  \
# 0      2  9D257416-581A-4C42-85CC-B6EAD9DED97F         2  1315925633
# 1      3  B80D7891-93CF-49E8-86E8-182B618E68F2         3  1315925633
# 2      4  BB012003-78F5-406D-8A87-7FF8A425EE3F         4  1315925633
# 3      5  945825F9-2F5D-47C2-A16B-75B93E61E1AD         5  1315925633
# 4      6  9546F502-39D6-4340-B37E-60682EB22274         6  1315925633
# ..   ...                                   ...       ...         ...
# 279  281  C50E6A4C-BDE9-4F12-97F4-95D467013540       281  1315925633
# 280  282  04C6D19F-FF63-47B0-B26D-3B8F98B4C16B       282  1315925633
# 281  283  A451E0E9-D382-4A97-AAD8-D7D382055F8D       283  1315925633
# 282  284  E84BCD0C-D6F4-450F-B55B-3199A265C781       284  1315925633
# 283  285  5BBC9676-2119-4FB5-9DAB-DE3F71B7681A       285  1315925633
#
#     created_meta  updated_at updated_meta  meta ELECTION CANDID  \
# 0         392904  1315925633       392904  {\n}     2001     B4
# 1         392904  1315925633       392904  {\n}     2001    445
# 2         392904  1315925633       392904  {\n}     2001     HF
# 3         392904  1315925633       392904  {\n}     2001     IR
# 4         392904  1315925633       392904  {\n}     2001     BR
# ..           ...         ...          ...   ...      ...    ...
# 279       392904  1315925633       392904  {\n}     2001    537
# 280       392904  1315925633       392904  {\n}     2001    559
# 281       392904  1315925633       392904  {\n}     2001    280
# 282       392904  1315925633       392904  {\n}     2001    274
# 283       392904  1315925633       392904  {\n}     2001    442
#
#                    CANDNAME OFFICECD OFFICEBORO OFFICEDIST CANCLASS  \
# 0          Aboulafia, Sandy        5       None         44        P
# 1           Adams, Jackie R        5       None          7        P
# 2         Addabbo, Joseph P        5       None         32        P
# 3    Alamo-Estrada, Agustin        5       None         14        P
# 4          Allen, William A        5       None          9        P
# ..                      ...      ...        ...        ...      ...
# 279          Wilson, John H        5       None         13        P
# 280        Wooten, Donald T        5       None         42        P
# 281           Yassky, David        5       None         33        P
# 282            Zapiti, Mike        5       None         22        P
# 283            Zett, Lori M        5       None         24        P
#
#     PRIMARYPAY GENERALPAY RUNOFFPAY   TOTALPAY
# 0     45410.00          0         0   45410.00
# 1     11073.00          0         0   11073.00
# 2     75350.00   73970.00         0  149320.00
# 3     25000.00    2400.00         0   27400.00
# 4     62990.00          0         0   62990.00
# ..         ...        ...       ...        ...
# 279          0          0         0          0
# 280          0          0         0          0
# 281   75350.00   75350.00         0  150700.00
# 282   12172.00          0         0   12172.00
# 283          0          0         0          0
#
# [284 rows x 19 columns]

# %% [markdown]
# ## Summary
#
# You've started exploring some more JSON data structures used for the web and got to practice data munging and exploring.
